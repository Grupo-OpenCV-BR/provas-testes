# %%
# !nvidia-smi
# Out:
# Tue Jan 12 23:26:45 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %%capture
# !git clone https://github.com/tensorflow/models.git
# !git clone https://github.com/cocodataset/cocoapi.git
# !cd cocoapi/PythonAPI; make; cp -r pycocotools /content/models/research/

# %%
# %%capture
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# !pip install -U --pre tensorflow=="2.*"
# !pip install tf_slim

# %%
# %cd /content/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/models/research

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models'

# %%
# %%capture
# !cd /content/models/research \
  && python setup.py build \
  && python setup.py install

# %%
# !cd /content/models/ \
  && python research/object_detection/builders/model_builder_test.py
# Out:
# 2021-01-12 23:27:36.476036: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
# !pip install -U albumentations
# Out:
# ...
#      |████████████████████████████████| 81kB 6.5MB/s
# ...
#      |████████████████████████████████| 952kB 14.7MB/s
# ...
#      |████████████████████████████████| 37.6MB 88kB/s
# ...
#   Found existing installation: imgaug 0.2.9
#     Uninstalling imgaug-0.2.9:
#       Successfully uninstalled imgaug-0.2.9
#   Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !cp -r /content/drive/MyDrive/wally /content/

# %%
import pprint

# %%
pp = pprint.PrettyPrinter(indent=2)

# %%
pp.pprint({"__version__": "0.5.2", "transform": {"__class_fullname__": "albumentations.core.composition.Compose", "p": 1.0, "transforms": [{"__class_fullname__": "albumentations.core.composition.OneOf", "p": 1, "transforms": [{"__class_fullname__": "albumentations.augmentations.transforms.Blur", "always_apply": "false", "p": 1, "blur_limit": [3, 7]}, {"__class_fullname__": "albumentations.augmentations.transforms.MotionBlur", "always_apply": "false", "p": 1, "blur_limit": [3, 20]}, {"__class_fullname__": "albumentations.augmentations.transforms.MedianBlur", "always_apply": "false", "p": 1, "blur_limit": [3, 15]}, {"__class_fullname__": "albumentations.augmentations.transforms.GaussianBlur", "always_apply": "false", "p": 1, "blur_limit": [3, 15]}]}, {"__class_fullname__": "albumentations.core.composition.OneOf", "p": 1, "transforms": [{"__class_fullname__": "albumentations.augmentations.transforms.ISONoise", "always_apply": "false", "p": 1, "intensity": [0.1, 1], "color_shift": [0.02, 0.1]}, {"__class_fullname__": "albumentations.augmentations.transforms.MultiplicativeNoise", "always_apply": "false", "p": 1, "multiplier": [0.75, 1.25], "per_channel": "false", "elementwise": "false"}, {"__class_fullname__": "albumentations.augmentations.transforms.MultiplicativeNoise", "always_apply": "false", "p": 1, "multiplier": [0.75, 1.25], "per_channel": "false", "elementwise": "true"}, {"__class_fullname__": "albumentations.augmentations.transforms.MultiplicativeNoise", "always_apply": "false", "p": 1, "multiplier": [0.75, 1.25], "per_channel": "true", "elementwise": "true"}, {"__class_fullname__": "albumentations.imgaug.transforms.IAAAdditiveGaussianNoise", "always_apply": "false", "p": 1, "loc": 0, "scale": [12.75, 25.5], "per_channel": "false"}, {"__class_fullname__": "albumentations.imgaug.transforms.IAAAdditiveGaussianNoise", "always_apply": "false", "p": 1, "loc": 0, "scale": [12.75, 25.5], "per_channel": "true"}]}, {"__class_fullname__": "albumentations.augmentations.transforms.RandomRotate90", "always_apply": "true", "p": 0.3}, {"__class_fullname__": "albumentations.augmentations.transforms.Rotate", "always_apply": "false", "p": 1, "limit": [-15, 15], "interpolation": 1, "border_mode": 0, "value": [255, 255, 255], "mask_value": "null"}, {"__class_fullname__": "albumentations.imgaug.transforms.IAAPerspective", "always_apply": "false", "p": 1, "scale": [0.05, 0.1], "keep_size": "true"}, {"__class_fullname__": "albumentations.augmentations.transforms.ToGray", "always_apply": "false", "p": 0.1}, {"__class_fullname__": "albumentations.augmentations.transforms.RandomBrightnessContrast", "always_apply": "false", "p": 1, "brightness_limit": [-0.2, 0.2], "contrast_limit": [-0.3, 0.3], "brightness_by_max": "false"}, {"__class_fullname__": "albumentations.imgaug.transforms.IAASharpen", "always_apply": "false", "p": 0.3, "alpha": [0.5, 1], "lightness": [1, 1]}, {"__class_fullname__": "albumentations.augmentations.transforms.RandomSunFlare", "always_apply": "false", "p": 0.3, "flare_roi": [0, 0, 1, 1], "angle_lower": 0, "angle_upper": 1, "num_flare_circles_lower": 0, "num_flare_circles_upper": 1, "src_radius": 200, "src_color": [255, 255, 255]}], "bbox_params": {"format": "albumentations", "label_fields": ["classes_text"], "min_area": 0.0, "min_visibility": 0.5}, "keypoint_params": "null", "additional_targets": {}}})
# Out:
# { '__version__': '0.5.2',
#   'transform': { '__class_fullname__': 'albumentations.core.composition.Compose',
#                  'additional_targets': {},
#                  'bbox_params': { 'format': 'albumentations',
#                                   'label_fields': ['classes_text'],
#                                   'min_area': 0.0,
#                                   'min_visibility': 0.5},
#                  'keypoint_params': 'null',
#                  'p': 1.0,
#                  'transforms': [ { '__class_fullname__': 'albumentations.core.composition.OneOf',
#                                    'p': 1,
#                                    'transforms': [ { '__class_fullname__': 'albumentations.augmentations.transforms.Blur',
#                                                      'always_apply': 'false',
#                                                      'blur_limit': [3, 7],
#                                                      'p': 1},
# ...

# %%
# !mkdir export

# %%
# !python generate_tfrecord.py \
    --anotations_dir="/content/wally/TrainingSet" \
    --output_dir="/content/export" \
    --desired_labels='' \
    --albumentations_transforms=""  \
    --base_path="/content/wally/TrainingSet" \
# Out:
# 2021-01-12 23:50:29.604158: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
# Settings and Creating Augmented Examples...
#
# Creating examples
# 100% 120/120 [00:04<00:00, 26.18it/s]
#
# TOTAL EXAMPLES : 120
# TRAIN EXAMPLES : 96
# TEST EXAMPLES  : 24
# TOTAL CLASSES  : 1
#     - document (1)
#
# Creating TFRecord (TRAINING SET)
# 100% 96/96 [00:00<00:00, 4842.03it/s]
#
# Creating TFRecord (TEST SET)
# 100% 24/24 [00:00<00:00, 3939.55it/s]

# %%
# !mv /content/export/* /content/drive/MyDrive/wally/tf_records/
